# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/MagicBricks.csv")
data
# Out:
#          Area  BHK  Bathroom      Furnishing  \
# 0       800.0    3       2.0  Semi-Furnished
# 1       750.0    2       2.0  Semi-Furnished
# 2       950.0    2       2.0       Furnished
# 3       600.0    2       2.0  Semi-Furnished
# 4       650.0    2       2.0  Semi-Furnished
# ...       ...  ...       ...             ...
# 1254   4118.0    4       5.0     Unfurnished
# 1255   1050.0    3       2.0  Semi-Furnished
# 1256    875.0    3       3.0  Semi-Furnished
# 1257    990.0    2       2.0     Unfurnished
# 1258  11050.0    3       3.0     Unfurnished
#
#                                                Locality  Parking     Price  \
# 0                                      Rohini Sector 25      1.0   6500000
# 1                J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                   Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                      Rohini Sector 24      1.0   4200000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Area         1259 non-null   float64
#  1   BHK          1259 non-null   int64
#  2   Bathroom     1257 non-null   float64
#  3   Furnishing   1254 non-null   object
#  4   Locality     1259 non-null   object
#  5   Parking      1226 non-null   float64
#  6   Price        1259 non-null   int64
#  7   Status       1259 non-null   object
#  8   Transaction  1259 non-null   object
#  9   Type         1254 non-null   object
#  10  Per_Sqft     1018 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 108.3+ KB

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#          Area  BHK  Bathroom      Furnishing  \
# 1       750.0    2       2.0  Semi-Furnished
# 2       950.0    2       2.0       Furnished
# 3       600.0    2       2.0  Semi-Furnished
# 4       650.0    2       2.0  Semi-Furnished
# 5      1300.0    4       3.0  Semi-Furnished
# ...       ...  ...       ...             ...
# 1254   4118.0    4       5.0     Unfurnished
# 1255   1050.0    3       2.0  Semi-Furnished
# 1256    875.0    3       3.0  Semi-Furnished
# 1257    990.0    2       2.0     Unfurnished
# 1258  11050.0    3       3.0     Unfurnished
#
#                                                Locality  Parking     Price  \
# 1                J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                   Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                      Rohini Sector 24      1.0   4200000
# 4     Rohini Sector 24 carpet area 650 sqft status R...      1.0   6200000
# ...

# %%
data.describe()
# Out:
#                Area          BHK     Bathroom      Parking         Price  \
# count   1005.000000  1005.000000  1005.000000  1005.000000  1.005000e+03
# mean    1504.301968     2.791045     2.575124     1.697512  2.224030e+07
# std     1729.104830     0.961469     1.088503     3.223118  2.771744e+07
# min       28.000000     1.000000     1.000000     1.000000  1.000000e+06
# 25%      770.000000     2.000000     2.000000     1.000000  5.130000e+06
# 50%     1150.000000     3.000000     2.000000     1.000000  1.400000e+07
# 75%     1700.000000     3.000000     3.000000     2.000000  2.700000e+07
# max    24300.000000     7.000000     7.000000    39.000000  2.400000e+08
#
#             Per_Sqft
# count    1005.000000
# mean    15663.630846
# std     21170.160448
# min      1259.000000
# 25%      6364.000000
# 50%     11363.000000
# 75%     18000.000000
# max    183333.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1005 entries, 1 to 1258
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Area         1005 non-null   float64
#  1   BHK          1005 non-null   int64
#  2   Bathroom     1005 non-null   float64
#  3   Furnishing   1005 non-null   object
#  4   Locality     1005 non-null   object
#  5   Parking      1005 non-null   float64
#  6   Price        1005 non-null   int64
#  7   Status       1005 non-null   object
#  8   Transaction  1005 non-null   object
#  9   Type         1005 non-null   object
#  10  Per_Sqft     1005 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 94.2+ KB

# %%
data.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'Area'}>,
#         <Axes: title={'center': 'BHK'}>],
#        [<Axes: title={'center': 'Bathroom'}>,
#         <Axes: title={'center': 'Parking'}>],
#        [<Axes: title={'center': 'Price'}>,
#         <Axes: title={'center': 'Per_Sqft'}>]], dtype=object)

# %%
data.corr(numeric_only=True)
# Out:
#               Area       BHK  Bathroom   Parking     Price  Per_Sqft
# Area      1.000000  0.463013  0.535153  0.004128  0.574410  0.165277
# BHK       0.463013  1.000000  0.811590 -0.085984  0.599587  0.181284
# Bathroom  0.535153  0.811590  1.000000 -0.030707  0.732241  0.220475
# Parking   0.004128 -0.085984 -0.030707  1.000000  0.035894  0.001607
# Price     0.574410  0.599587  0.732241  0.035894  1.000000  0.325240
# Per_Sqft  0.165277  0.181284  0.220475  0.001607  0.325240  1.000000

# %%
data
# Out:
#          Area  BHK  Bathroom      Furnishing  \
# 1       750.0    2       2.0  Semi-Furnished
# 2       950.0    2       2.0       Furnished
# 3       600.0    2       2.0  Semi-Furnished
# 4       650.0    2       2.0  Semi-Furnished
# 5      1300.0    4       3.0  Semi-Furnished
# ...       ...  ...       ...             ...
# 1254   4118.0    4       5.0     Unfurnished
# 1255   1050.0    3       2.0  Semi-Furnished
# 1256    875.0    3       3.0  Semi-Furnished
# 1257    990.0    2       2.0     Unfurnished
# 1258  11050.0    3       3.0     Unfurnished
#
#                                                Locality  Parking     Price  \
# 1                J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                   Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                      Rohini Sector 24      1.0   4200000
# 4     Rohini Sector 24 carpet area 650 sqft status R...      1.0   6200000
# ...

# %%
for column in data.columns:
    if column != 'Price':
        sns.scatterplot(x=data[column], y=data['Price'])
        plt.show()

# %%
data=data.drop('Locality',axis=1)

# %%
data
# Out:
#          Area  BHK  Bathroom      Furnishing  Parking     Price  \
# 1       750.0    2       2.0  Semi-Furnished      1.0   5000000
# 2       950.0    2       2.0       Furnished      1.0  15500000
# 3       600.0    2       2.0  Semi-Furnished      1.0   4200000
# 4       650.0    2       2.0  Semi-Furnished      1.0   6200000
# 5      1300.0    4       3.0  Semi-Furnished      1.0  15500000
# ...       ...  ...       ...             ...      ...       ...
# 1254   4118.0    4       5.0     Unfurnished      3.0  55000000
# 1255   1050.0    3       2.0  Semi-Furnished      3.0  12500000
# 1256    875.0    3       3.0  Semi-Furnished      3.0  17500000
# 1257    990.0    2       2.0     Unfurnished      1.0  11500000
# 1258  11050.0    3       3.0     Unfurnished      1.0  18500000
#
#              Status   Transaction           Type  Per_Sqft
# 1     Ready_to_move  New_Property      Apartment    6667.0
# 2     Ready_to_move        Resale      Apartment    6667.0
# ...

# %%
numerical_cols = list(data.select_dtypes(include=np.number))
categorical_cols = list(data.select_dtypes(include=object))
categorical_cols
# Out:
# ['Furnishing', 'Status', 'Transaction', 'Type']

# %%
data[numerical_cols]
# Out:
#          Area  BHK  Bathroom  Parking     Price  Per_Sqft
# 1       750.0    2       2.0      1.0   5000000    6667.0
# 2       950.0    2       2.0      1.0  15500000    6667.0
# 3       600.0    2       2.0      1.0   4200000    6667.0
# 4       650.0    2       2.0      1.0   6200000    6667.0
# 5      1300.0    4       3.0      1.0  15500000    6667.0
# ...       ...  ...       ...      ...       ...       ...
# 1254   4118.0    4       5.0      3.0  55000000   12916.0
# 1255   1050.0    3       2.0      3.0  12500000   12916.0
# 1256    875.0    3       3.0      3.0  17500000   12916.0
# 1257    990.0    2       2.0      1.0  11500000   12916.0
# 1258  11050.0    3       3.0      1.0  18500000   12916.0
#
# [1005 rows x 6 columns]

# %%
data[categorical_cols]
# Out:
#           Furnishing         Status   Transaction           Type
# 1     Semi-Furnished  Ready_to_move  New_Property      Apartment
# 2          Furnished  Ready_to_move        Resale      Apartment
# 3     Semi-Furnished  Ready_to_move        Resale  Builder_Floor
# 4     Semi-Furnished  Ready_to_move  New_Property  Builder_Floor
# 5     Semi-Furnished  Ready_to_move  New_Property  Builder_Floor
# ...              ...            ...           ...            ...
# 1254     Unfurnished  Ready_to_move  New_Property  Builder_Floor
# 1255  Semi-Furnished  Ready_to_move        Resale  Builder_Floor
# 1256  Semi-Furnished  Ready_to_move  New_Property  Builder_Floor
# 1257     Unfurnished  Ready_to_move        Resale  Builder_Floor
# 1258     Unfurnished  Ready_to_move  New_Property  Builder_Floor
#
# [1005 rows x 4 columns]

# %%
data_cat_encoded = pd.get_dummies(data[categorical_cols])
data_cat_encoded
# Out:
#       Furnishing_Furnished  Furnishing_Semi-Furnished  Furnishing_Unfurnished  \
# 1                    False                       True                   False
# 2                     True                      False                   False
# 3                    False                       True                   False
# 4                    False                       True                   False
# 5                    False                       True                   False
# ...                    ...                        ...                     ...
# 1254                 False                      False                    True
# 1255                 False                       True                   False
# 1256                 False                       True                   False
# 1257                 False                      False                    True
# 1258                 False                      False                    True
#
# ...

# %%
data[numerical_cols]
# Out:
#          Area  BHK  Bathroom  Parking     Price  Per_Sqft
# 1       750.0    2       2.0      1.0   5000000    6667.0
# 2       950.0    2       2.0      1.0  15500000    6667.0
# 3       600.0    2       2.0      1.0   4200000    6667.0
# 4       650.0    2       2.0      1.0   6200000    6667.0
# 5      1300.0    4       3.0      1.0  15500000    6667.0
# ...       ...  ...       ...      ...       ...       ...
# 1254   4118.0    4       5.0      3.0  55000000   12916.0
# 1255   1050.0    3       2.0      3.0  12500000   12916.0
# 1256    875.0    3       3.0      3.0  17500000   12916.0
# 1257    990.0    2       2.0      1.0  11500000   12916.0
# 1258  11050.0    3       3.0      1.0  18500000   12916.0
#
# [1005 rows x 6 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data[numerical_cols] = scaler.fit_transform(data[numerical_cols])

# %%
data[numerical_cols]
# Out:
#           Area       BHK  Bathroom   Parking     Price  Per_Sqft
# 1     0.029746  0.166667  0.166667  0.000000  0.016736  0.029702
# 2     0.037986  0.166667  0.166667  0.000000  0.060669  0.029702
# 3     0.023566  0.166667  0.166667  0.000000  0.013389  0.029702
# 4     0.025626  0.166667  0.166667  0.000000  0.021757  0.029702
# 5     0.052406  0.500000  0.333333  0.000000  0.060669  0.029702
# ...        ...       ...       ...       ...       ...       ...
# 1254  0.168507  0.500000  0.666667  0.052632  0.225941  0.064023
# 1255  0.042106  0.333333  0.166667  0.052632  0.048117  0.064023
# 1256  0.034896  0.333333  0.333333  0.052632  0.069038  0.064023
# 1257  0.039634  0.166667  0.166667  0.000000  0.043933  0.064023
# 1258  0.454103  0.333333  0.333333  0.000000  0.073222  0.064023
#
# [1005 rows x 6 columns]

# %%
final_data=pd.concat([data[numerical_cols],data_cat_encoded],axis=1)
final_data
# Out:
#           Area       BHK  Bathroom   Parking     Price  Per_Sqft  \
# 1     0.029746  0.166667  0.166667  0.000000  0.016736  0.029702
# 2     0.037986  0.166667  0.166667  0.000000  0.060669  0.029702
# 3     0.023566  0.166667  0.166667  0.000000  0.013389  0.029702
# 4     0.025626  0.166667  0.166667  0.000000  0.021757  0.029702
# 5     0.052406  0.500000  0.333333  0.000000  0.060669  0.029702
# ...        ...       ...       ...       ...       ...       ...
# 1254  0.168507  0.500000  0.666667  0.052632  0.225941  0.064023
# 1255  0.042106  0.333333  0.166667  0.052632  0.048117  0.064023
# 1256  0.034896  0.333333  0.333333  0.052632  0.069038  0.064023
# 1257  0.039634  0.166667  0.166667  0.000000  0.043933  0.064023
# 1258  0.454103  0.333333  0.333333  0.000000  0.073222  0.064023
#
#       Furnishing_Furnished  Furnishing_Semi-Furnished  Furnishing_Unfurnished  \
# 1                    False                       True                   False
# ...

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(final_data.corr(), annot=True)
plt.show()

# %%
y=final_data['Price']
x=final_data.drop('Price',axis=1)

# %%
x
# Out:
#           Area       BHK  Bathroom   Parking  Per_Sqft  Furnishing_Furnished  \
# 1     0.029746  0.166667  0.166667  0.000000  0.029702                 False
# 2     0.037986  0.166667  0.166667  0.000000  0.029702                  True
# 3     0.023566  0.166667  0.166667  0.000000  0.029702                 False
# 4     0.025626  0.166667  0.166667  0.000000  0.029702                 False
# 5     0.052406  0.500000  0.333333  0.000000  0.029702                 False
# ...        ...       ...       ...       ...       ...                   ...
# 1254  0.168507  0.500000  0.666667  0.052632  0.064023                 False
# 1255  0.042106  0.333333  0.166667  0.052632  0.064023                 False
# 1256  0.034896  0.333333  0.333333  0.052632  0.064023                 False
# 1257  0.039634  0.166667  0.166667  0.000000  0.064023                 False
# 1258  0.454103  0.333333  0.333333  0.000000  0.064023                 False
#
# ...

# %%
y
# Out:
# 1       0.016736
# 2       0.060669
# 3       0.013389
# 4       0.021757
# 5       0.060669
#           ...
# 1254    0.225941
# 1255    0.048117
# 1256    0.069038
# 1257    0.043933
# 1258    0.073222
# Name: Price, Length: 1005, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=101)

# %%
# from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
# from sklearn.preprocessing import PolynomialFeatures
# from sklearn.tree import DecisionTreeRegressor
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.svm import SVR
# from sklearn.neighbors import KNeighborsRegressor
# from sklearn.ensemble import GradientBoostingRegressor

# regressors = [
#     LinearRegression(),
#     Ridge(),
#     Lasso(),
#     ElasticNet(),
#     # PolynomialFeatures(),
#     DecisionTreeRegressor(),
#     RandomForestRegressor(),
#     SVR(),
#     KNeighborsRegressor(),
#     GradientBoostingRegressor()
# ]

# for regressor in regressors:
#     regressor.fit(X_train, y_train)
#     score = regressor.score(X_test, y_test)
#     print(f"{regressor.__class__.__name__}: {score}")
# Out:
# LinearRegression: 0.6802542788355637
# Ridge: 0.6653836589718247
# Lasso: -0.007266522870077896
# ElasticNet: -0.007266522870077896
# DecisionTreeRegressor: 0.6536602337402595
# RandomForestRegressor: 0.7652423746167518
# SVR: 0.6272938099799545
# KNeighborsRegressor: 0.6205777610457146
# GradientBoostingRegressor: 0.8074833411035713

# %%
# from sklearn.ensemble import RandomForestRegressor

# rfr = RandomForestRegressor()

# rfr.fit(X_train, y_train)

# score = rfr.score(X_test, y_test)

# print(f"Random Forest Regressor: {score}")
# Out:
# Random Forest Regressor: 0.7813982539301402

# %%
# from sklearn.ensemble import GradientBoostingRegressor

# gbr = GradientBoostingRegressor()

# gbr.fit(X_train, y_train)

# score = gbr.score(X_test, y_test)

# print(f"Gradient Boosting Regressor: {score}")
# Out:
# Gradient Boosting Regressor: 0.8137900910876721

# %%
# from sklearn.model_selection import GridSearchCV

# grid = {
#     'criterion': ['squared_error', 'absolute_error'],
#     'max_depth': [None, 10, 20],
#     'n_estimators': [50, 100, 200],
#     'min_samples_leaf': [1, 5, 8]
# }

# rfr = RandomForestRegressor()

# grid_search = GridSearchCV(rfr, grid, cv=5)

# grid_search.fit(X_train, y_train)

# best_params = grid_search.best_params_

# print(f"Best parameters: {best_params}")

# rfr_best = RandomForestRegressor(**best_params)

# rfr_best.fit(X_train, y_train)

# score = rfr_best.score(X_test, y_test)

# print(f"Random Forest Regressor (best parameters): {score}")
# Out:
# Best parameters: {'criterion': 'absolute_error', 'max_depth': 20, 'min_samples_leaf': 1, 'n_estimators': 50}
# Random Forest Regressor (best parameters): 0.8128107650291363

# %%
# grid = {
#     # 'loss': ['squared_error', 'absolute_error'],
#     # 'learning_rate': [0.1, 0.3, 0.5],
#     'n_estimators': [300,400],
#     'max_depth': [15,20]
# }

# gbr = GradientBoostingRegressor()

# grid_search = GridSearchCV(gbr, grid, cv=5)

# grid_search.fit(X_train, y_train)

# best_params = grid_search.best_params_

# print(f"Best parameters: {best_params}")

# gbr_best = GradientBoostingRegressor(**best_params)

# gbr_best.fit(X_train, y_train)

# score = gbr_best.score(X_test, y_test)

# print(f"Gradient Boosting Regressor (best parameters): {score}")

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor()

gbr.fit(X_train, y_train)

score = gbr.score(X_train, y_train)

print(f"Score On Train Data is --> : {score*100}\n")

score = gbr.score(X_test, y_test)

print(f"Score On Test Data is --> : {score*100}")
# Out:
# Score On Train Data is --> : 95.29739184933206
#
# Score On Test Data is --> : 81.49161709427332

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(gbr.predict(X_test), y_test_arr, squared=False)
# Out:
# 0.051914151097847167

# %%
sns.scatterplot(x=y_test_arr, y=gbr.predict(X_test))
# Out:
# <Axes: >
