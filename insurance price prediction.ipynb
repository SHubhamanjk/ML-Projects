# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/insurance.csv')
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
sns.scatterplot(x='age',y='charges',data=data,hue='smoker')
plt.show()

# %%
sns.barplot(x='sex', y='charges', hue='smoker', data=data)
plt.show()

# %%
sns.barplot(x='children',y='charges', hue='smoker', data=data)
plt.show()

# %%
sns.barplot(x='smoker', y='charges', data=data)
plt.show()

# %%
sns.barplot(x='region', y='charges', data=data,hue='smoker')
plt.show()

# %%
sns.lineplot(x='bmi',y='charges',data=data,hue='smoker')
plt.show()

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# So after analyzing the data conclusion is this , i should divide the data into two parts ... one for smokers and second for non smokers because of this line will be not perfect fit.

# %%
data_smoker= data[data['smoker']=='yes']
data_smoker=data_smoker.drop('smoker',axis=1)
data_smoker
# Out:
#       age     sex     bmi  children     region      charges
# 0      19  female  27.900         0  southwest  16884.92400
# 11     62  female  26.290         0  southeast  27808.72510
# 14     27    male  42.130         0  southeast  39611.75770
# 19     30    male  35.300         0  southwest  36837.46700
# 23     34  female  31.920         1  northeast  37701.87680
# ...   ...     ...     ...       ...        ...          ...
# 1313   19  female  34.700         2  southwest  36397.57600
# 1314   30  female  23.655         3  northwest  18765.87545
# 1321   62    male  26.695         0  northeast  28101.33305
# 1323   42  female  40.370         2  southeast  43896.37630
# 1337   61  female  29.070         0  northwest  29141.36030
#
# [274 rows x 6 columns]

# %%
data_non_smoker= data[data['smoker']=='no']
data_non_smoker=data_non_smoker.drop('smoker',axis=1)
data_non_smoker
# Out:
#       age     sex     bmi  children     region      charges
# 1      18    male  33.770         1  southeast   1725.55230
# 2      28    male  33.000         3  southeast   4449.46200
# 3      33    male  22.705         0  northwest  21984.47061
# 4      32    male  28.880         0  northwest   3866.85520
# 5      31  female  25.740         0  southeast   3756.62160
# ...   ...     ...     ...       ...        ...          ...
# 1332   52  female  44.700         3  southwest  11411.68500
# 1333   50    male  30.970         3  northwest  10600.54830
# 1334   18  female  31.920         0  northeast   2205.98080
# 1335   18  female  36.850         0  southeast   1629.83350
# 1336   21  female  25.800         0  southwest   2007.94500
#
# [1064 rows x 6 columns]

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
data_smoker
# Out:
#       age     sex     bmi  children     region      charges
# 0      19  female  27.900         0  southwest  16884.92400
# 11     62  female  26.290         0  southeast  27808.72510
# 14     27    male  42.130         0  southeast  39611.75770
# 19     30    male  35.300         0  southwest  36837.46700
# 23     34  female  31.920         1  northeast  37701.87680
# ...   ...     ...     ...       ...        ...          ...
# 1313   19  female  34.700         2  southwest  36397.57600
# 1314   30  female  23.655         3  northwest  18765.87545
# 1321   62    male  26.695         0  northeast  28101.33305
# 1323   42  female  40.370         2  southeast  43896.37630
# 1337   61  female  29.070         0  northwest  29141.36030
#
# [274 rows x 6 columns]

# %%
sns.scatterplot(x='age',y='charges',data=data_smoker,hue='sex')
plt.show()

# %%
sns.scatterplot(x='age',y='charges',data=data_smoker,hue='sex',markers='x',palette='coolwarm')
sns.scatterplot(x='bmi',y='charges',data=data_smoker,markers='x')
plt.show()

# %%
sns.barplot(x='region', y='charges', data=data_smoker,hue='sex')
plt.show()

# %%
sns.barplot(x='children', y='charges', data=data_smoker,hue='sex')
plt.show()

# %%
data_smoker
# Out:
#       age     sex     bmi  children     region      charges
# 0      19  female  27.900         0  southwest  16884.92400
# 11     62  female  26.290         0  southeast  27808.72510
# 14     27    male  42.130         0  southeast  39611.75770
# 19     30    male  35.300         0  southwest  36837.46700
# 23     34  female  31.920         1  northeast  37701.87680
# ...   ...     ...     ...       ...        ...          ...
# 1313   19  female  34.700         2  southwest  36397.57600
# 1314   30  female  23.655         3  northwest  18765.87545
# 1321   62    male  26.695         0  northeast  28101.33305
# 1323   42  female  40.370         2  southeast  43896.37630
# 1337   61  female  29.070         0  northwest  29141.36030
#
# [274 rows x 6 columns]

# %%
data_smoker
# Out:
#       age     sex     bmi  children     region      charges
# 0      19  female  27.900         0  southwest  16884.92400
# 11     62  female  26.290         0  southeast  27808.72510
# 14     27    male  42.130         0  southeast  39611.75770
# 19     30    male  35.300         0  southwest  36837.46700
# 23     34  female  31.920         1  northeast  37701.87680
# ...   ...     ...     ...       ...        ...          ...
# 1313   19  female  34.700         2  southwest  36397.57600
# 1314   30  female  23.655         3  northwest  18765.87545
# 1321   62    male  26.695         0  northeast  28101.33305
# 1323   42  female  40.370         2  southeast  43896.37630
# 1337   61  female  29.070         0  northwest  29141.36030
#
# [274 rows x 6 columns]

# %% [markdown]
# if we see in smoker case , age and bmi is biggest factor while predicting the price.

# %%
sns.scatterplot(x='age',y='charges',data=data_non_smoker,hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %%
sns.scatterplot(x='bmi',y='charges',data=data_non_smoker,hue='sex')
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sns.barplot(x='sex',y='charges',data=data_non_smoker)
# Out:
# <Axes: xlabel='sex', ylabel='charges'>

# %%
sns.barplot(x='children',y='charges',data=data_non_smoker)
# Out:
# <Axes: xlabel='children', ylabel='charges'>

# %%
sns.barplot(x='region',y='charges',data=data_non_smoker)
# Out:
# <Axes: xlabel='region', ylabel='charges'>

# %%
data_non_smoker
# Out:
#       age     sex     bmi  children     region      charges
# 1      18    male  33.770         1  southeast   1725.55230
# 2      28    male  33.000         3  southeast   4449.46200
# 3      33    male  22.705         0  northwest  21984.47061
# 4      32    male  28.880         0  northwest   3866.85520
# 5      31  female  25.740         0  southeast   3756.62160
# ...   ...     ...     ...       ...        ...          ...
# 1332   52  female  44.700         3  southwest  11411.68500
# 1333   50    male  30.970         3  northwest  10600.54830
# 1334   18  female  31.920         0  northeast   2205.98080
# 1335   18  female  36.850         0  southeast   1629.83350
# 1336   21  female  25.800         0  southwest   2007.94500
#
# [1064 rows x 6 columns]

# %%
data_smoker
# Out:
#       age     sex     bmi  children     region      charges
# 0      19  female  27.900         0  southwest  16884.92400
# 11     62  female  26.290         0  southeast  27808.72510
# 14     27    male  42.130         0  southeast  39611.75770
# 19     30    male  35.300         0  southwest  36837.46700
# 23     34  female  31.920         1  northeast  37701.87680
# ...   ...     ...     ...       ...        ...          ...
# 1313   19  female  34.700         2  southwest  36397.57600
# 1314   30  female  23.655         3  northwest  18765.87545
# 1321   62    male  26.695         0  northeast  28101.33305
# 1323   42  female  40.370         2  southeast  43896.37630
# 1337   61  female  29.070         0  northwest  29141.36030
#
# [274 rows x 6 columns]

# %%
numerical_cols= ['age','bmi','children','charges']
categorical_cols= ['sex','region']

# %%
data_smoker[numerical_cols].corr()
# Out:
#                age       bmi  children   charges
# age       1.000000  0.059674  0.081183  0.368224
# bmi       0.059674  1.000000 -0.012619  0.806481
# children  0.081183 -0.012619  1.000000  0.035945
# charges   0.368224  0.806481  0.035945  1.000000

# %%
data_non_smoker[numerical_cols].corr()
# Out:
#                age       bmi  children   charges
# age       1.000000  0.122638  0.033395  0.627947
# bmi       0.122638  1.000000  0.019208  0.084037
# children  0.033395  0.019208  1.000000  0.138929
# charges   0.627947  0.084037  0.138929  1.000000

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

data_smoker[numerical_cols] = scaler.fit_transform(data_smoker[numerical_cols])
data_smoker[numerical_cols]
# Out:
#            age       bmi  children   charges
# 0     0.021739  0.302529       0.0  0.079611
# 11    0.956522  0.257030       0.0  0.294052
# 14    0.195652  0.704677       0.0  0.525752
# 19    0.260870  0.511657       0.0  0.471291
# 23    0.347826  0.416137       0.2  0.488260
# ...        ...       ...       ...       ...
# 1313  0.021739  0.494701       0.4  0.462655
# 1314  0.260870  0.182563       0.6  0.116535
# 1321  0.956522  0.268475       0.0  0.299796
# 1323  0.521739  0.654939       0.4  0.609861
# 1337  0.934783  0.335594       0.0  0.320212
#
# [274 rows x 4 columns]

# %%
scaler2=MinMaxScaler()
data_non_smoker[numerical_cols]=scaler2.fit_transform(data_non_smoker[numerical_cols])
data_non_smoker[numerical_cols]
# Out:
#            age       bmi  children   charges
# 1     0.000000  0.479150       0.2  0.016868
# 2     0.217391  0.458434       0.6  0.092979
# 3     0.326087  0.181464       0.0  0.582938
# 4     0.304348  0.347592       0.0  0.076700
# 5     0.282609  0.263115       0.0  0.073619
# ...        ...       ...       ...       ...
# 1332  0.739130  0.773204       0.6  0.287515
# 1333  0.695652  0.403820       0.6  0.264851
# 1334  0.000000  0.429379       0.0  0.030292
# 1335  0.000000  0.562012       0.0  0.014193
# 1336  0.065217  0.264730       0.0  0.024758
#
# [1064 rows x 4 columns]

# %%
data_smoker[numerical_cols].corr()
# Out:
#                age       bmi  children   charges
# age       1.000000  0.059674  0.081183  0.368224
# bmi       0.059674  1.000000 -0.012619  0.806481
# children  0.081183 -0.012619  1.000000  0.035945
# charges   0.368224  0.806481  0.035945  1.000000

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in categorical_cols:
  data_smoker[col] = le.fit_transform(data_smoker[col])
data_smoker
# Out:
#            age  sex       bmi  children  region   charges
# 0     0.021739    0  0.302529       0.0       3  0.079611
# 11    0.956522    0  0.257030       0.0       2  0.294052
# 14    0.195652    1  0.704677       0.0       2  0.525752
# 19    0.260870    1  0.511657       0.0       3  0.471291
# 23    0.347826    0  0.416137       0.2       0  0.488260
# ...        ...  ...       ...       ...     ...       ...
# 1313  0.021739    0  0.494701       0.4       3  0.462655
# 1314  0.260870    0  0.182563       0.6       1  0.116535
# 1321  0.956522    1  0.268475       0.0       0  0.299796
# 1323  0.521739    0  0.654939       0.4       2  0.609861
# 1337  0.934783    0  0.335594       0.0       1  0.320212
#
# [274 rows x 6 columns]

# %%
# from sklearn.preprocessing import LabelEncoder
le2 = LabelEncoder()
for col in categorical_cols:
  data_non_smoker[col] = le2.fit_transform(data_non_smoker[col])
data_non_smoker
# Out:
#            age  sex       bmi  children  region   charges
# 1     0.000000    1  0.479150       0.2       2  0.016868
# 2     0.217391    1  0.458434       0.6       2  0.092979
# 3     0.326087    1  0.181464       0.0       1  0.582938
# 4     0.304348    1  0.347592       0.0       1  0.076700
# 5     0.282609    0  0.263115       0.0       2  0.073619
# ...        ...  ...       ...       ...     ...       ...
# 1332  0.739130    0  0.773204       0.6       3  0.287515
# 1333  0.695652    1  0.403820       0.6       1  0.264851
# 1334  0.000000    0  0.429379       0.0       0  0.030292
# 1335  0.000000    0  0.562012       0.0       2  0.014193
# 1336  0.065217    0  0.264730       0.0       3  0.024758
#
# [1064 rows x 6 columns]

# %%
data_smoker.corr()
# Out:
#                age       sex       bmi  children    region   charges
# age       1.000000 -0.005758  0.059674  0.081183 -0.036548  0.368224
# sex      -0.005758  1.000000  0.148350  0.076907  0.066943  0.101226
# bmi       0.059674  0.148350  1.000000 -0.012619  0.212198  0.806481
# children  0.081183  0.076907 -0.012619  1.000000  0.015126  0.035945
# region   -0.036548  0.066943  0.212198  0.015126  1.000000  0.128983
# charges   0.368224  0.101226  0.806481  0.035945  0.128983  1.000000

# %%
data_non_smoker.corr()
# Out:
#                age       sex       bmi  children    region   charges
# age       1.000000 -0.022338  0.122638  0.033395  0.011601  0.627947
# sex      -0.022338  1.000000  0.019119  0.002090 -0.010571 -0.056320
# bmi       0.122638  0.019119  1.000000  0.019208  0.143413  0.084037
# children  0.033395  0.002090  0.019208  1.000000  0.016934  0.138929
# region    0.011601 -0.010571  0.143413  0.016934  1.000000 -0.073316
# charges   0.627947 -0.056320  0.084037  0.138929 -0.073316  1.000000

# %%
X=data_smoker[['age','sex','bmi','children','region']]
y=data_smoker[['charges']]
X
# Out:
#            age  sex       bmi  children  region
# 0     0.021739    0  0.302529       0.0       3
# 11    0.956522    0  0.257030       0.0       2
# 14    0.195652    1  0.704677       0.0       2
# 19    0.260870    1  0.511657       0.0       3
# 23    0.347826    0  0.416137       0.2       0
# ...        ...  ...       ...       ...     ...
# 1313  0.021739    0  0.494701       0.4       3
# 1314  0.260870    0  0.182563       0.6       1
# 1321  0.956522    1  0.268475       0.0       0
# 1323  0.521739    0  0.654939       0.4       2
# 1337  0.934783    0  0.335594       0.0       1
#
# [274 rows x 5 columns]

# %%
X1=data_non_smoker[['age','sex','bmi','children','region']]
y1=data_non_smoker[['charges']]

# %%
y
# Out:
#        charges
# 0     0.079611
# 11    0.294052
# 14    0.525752
# 19    0.471291
# 23    0.488260
# ...        ...
# 1313  0.462655
# 1314  0.116535
# 1321  0.299796
# 1323  0.609861
# 1337  0.320212
#
# [274 rows x 1 columns]

# %%
# prompt: spilit X and y in train and test dataset

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.model_selection import train_test_split

X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.4, random_state=452)

# %%
# from sklearn.linear_model import LinearRegression
# from sklearn.preprocessing import PolynomialFeatures
# from sklearn.tree import DecisionTreeRegressor
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.svm import SVR
# from sklearn.ensemble import GradientBoostingRegressor

# # Train a linear regression model
# linear_model = LinearRegression()
# linear_model.fit(X_train, y_train)
# linear_score = linear_model.score(X_test, y_test)

# # Train a polynomial regression model
# poly_features = PolynomialFeatures(degree=2)
# X_train_poly = poly_features.fit_transform(X_train)
# X_test_poly = poly_features.transform(X_test)
# poly_model = LinearRegression()
# poly_model.fit(X_train_poly, y_train)
# poly_score = poly_model.score(X_test_poly, y_test)

# # Train a decision tree regressor model
# tree_model = DecisionTreeRegressor()
# tree_model.fit(X_train, y_train)
# tree_score = tree_model.score(X_test, y_test)

# # Train a random forest regressor model
# forest_model = RandomForestRegressor()
# forest_model.fit(X_train, y_train)
# forest_score = forest_model.score(X_test, y_test)

# # Train a support vector regressor model
# svr_model = SVR()
# svr_model.fit(X_train, y_train)
# svr_score = svr_model.score(X_test, y_test)

# # Train a gradient boosting regressor model
# gboost_model = GradientBoostingRegressor()
# gboost_model.fit(X_train, y_train)
# gboost_score = gboost_model.score(X_test, y_test)

# # Print the scores of each model
# print("Linear Regression score:", linear_score)
# print("Polynomial Regression score:", poly_score)
# print("Decision Tree Regressor score:", tree_score)
# print("Random Forest Regressor score:", forest_score)
# print("Support Vector Regressor score:", svr_score)
# print("Gradient Boosting Regressor score:", gboost_score)
# Out:
# <ipython-input-109-e1c676c4d76c>:30: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   forest_model.fit(X_train, y_train)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Linear Regression score: 0.6837289882361297
# Polynomial Regression score: 0.7099936976700159
# Decision Tree Regressor score: 0.8524985630632036
# Random Forest Regressor score: 0.8684987120976658
# ...

# %%
# from sklearn.linear_model import LinearRegression
# from sklearn.preprocessing import PolynomialFeatures
# from sklearn.tree import DecisionTreeRegressor
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.svm import SVR
# from sklearn.ensemble import GradientBoostingRegressor

# # Train a linear regression model
# linear_model = LinearRegression()
# linear_model.fit(X1_train, y1_train)
# linear_score = linear_model.score(X1_train, y1_train)

# # Train a polynomial regression model
# poly_features = PolynomialFeatures(degree=2)
# X1_train_poly = poly_features.fit_transform(X1_train)
# X1_test_poly = poly_features.transform(X1_test)
# poly_model = LinearRegression()
# poly_model.fit(X1_train_poly, y1_train)
# poly_score = poly_model.score(X1_test_poly, y1_test)

# # Train a decision tree regressor model
# tree_model = DecisionTreeRegressor()
# tree_model.fit(X1_train, y1_train)
# tree_score = tree_model.score(X1_test, y1_test)

# # Train a random forest regressor model
# forest_model = RandomForestRegressor()
# forest_model.fit(X1_train, y1_train)
# forest_score = forest_model.score(X1_test, y1_test)

# # Train a support vector regressor model
# svr_model = SVR()
# svr_model.fit(X1_train, y1_train)
# svr_score = svr_model.score(X1_test, y1_test)

# # Train a gradient boosting regressor model
# gboost_model = GradientBoostingRegressor()
# gboost_model.fit(X1_train, y1_train)
# gboost_score = gboost_model.score(X1_test, y1_test)

# # Print the scores of each model
# print("Linear Regression score:", linear_score)
# print("Polynomial Regression score:", poly_score)
# print("Decision Tree Regressor score:", tree_score)
# print("Random Forest Regressor score:", forest_score)
# print("Support Vector Regressor score:", svr_score)
# print("Gradient Boosting Regressor score:", gboost_score)
# Out:
# <ipython-input-142-f2a51718a0b5>:30: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   forest_model.fit(X1_train, y1_train)
# Linear Regression score: 0.41957878295528916
# Polynomial Regression score: 0.3936904944151929
# Decision Tree Regressor score: -0.20265902003687253
# Random Forest Regressor score: 0.29387205630579627
# Support Vector Regressor score: 0.33318249774262965
# Gradient Boosting Regressor score: 0.3450673220935664
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.model_selection import GridSearchCV

# # Define the parameter grid
# param_grid = {
#     'n_estimators': [10, 50, 100, 150, 200],
#     'max_depth': [None, 5, 10, 15, 20],
#     'min_samples_split': [2, 5, 10, 15, 20],
#     'min_samples_leaf': [1, 2, 5, 10],
#     'max_features': ['auto', 'sqrt', 'log2', None]
# }

# # Create a Random Forest Regressor
# rf = RandomForestRegressor()

# # Instantiate the GridSearchCV object
# grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5)

# # Fit the grid search to the training data
# grid_search.fit(X_train, y_train)

# # Get the best set of parameters
# best_params = grid_search.best_params_

# # Print the best parameters
# print("Best parameters:", best_params)

# # Get the best model
# best_model = grid_search.best_estimator_

# # Evaluate the best model on the test data
# best_model_score = best_model.score(X_test, y_test)

# # Print the best model score
# print("Best model score:", best_model_score)

# %%
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.model_selection import RandomizedSearchCV

# # Define the parameter grid
# param_grid = {
#     'n_estimators': [10, 50, 100, 150, 200],
#     'max_depth': [None, 5, 10, 15, 20],
#     'min_samples_split': [2, 5, 10, 15, 20],
#     'min_samples_leaf': [1, 2, 5, 10],
#     'max_features': ['auto', 'sqrt', 'log2', None]
# }

# # Create a Random Forest Regressor
# rf = RandomForestRegressor()

# # Instantiate the RandomizedSearchCV object
# random_search = RandomizedSearchCV(estimator=rf, param_distributions=param_grid, cv=5, n_iter=10, random_state=42)

# # Fit the random search to the training data
# random_search.fit(X_train, y_train)

# # Get the best set of parameters
# best_params = random_search.best_params_

# # Print the best parameters
# print("Best parameters:", best_params)

# # Get the best model
# best_model = random_search.best_estimator_

# # Evaluate the best model on the test data
# best_model_score = best_model.score(X_test, y_test)

# # Print the best model score
# print("Best model score:", best_model_score)

# %%
# best_model_score = best_model.score(X_test, y_test)

# print("Best parameters:", best_params)
# # Print the best model score
# print("Best model score:", best_model_score)
# Out:
# Best parameters: {'n_estimators': 200, 'min_samples_split': 15, 'min_samples_leaf': 10, 'max_features': 'auto', 'max_depth': 15}
# Best model score: 0.8665382341032937

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(X_train, y_train)
# Out:
# <ipython-input-124-0e2b706809eb>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# RandomForestRegressor()

# %%
rf.score(X_test, y_test)
# Out:
# 0.8717133422235609

# %%
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression()
linear_model.fit(X1_train, y1_train)
model_score = linear_model.score(X1_train, y1_train)

print("Model score:", model_score)
# Out:
# Model score: 0.41957878295528916
