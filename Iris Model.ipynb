# %% [markdown]
# # Reading DataSet

# %%
# prompt: import pandas , numpy , matplot , seaborn libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# prompt: import iris dataset from sklearn and convert it to dataframe

import pandas as pd
from sklearn.datasets import load_iris
iris = load_iris()
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_df['species'] = iris.target

iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      species
# 0          0
# ...

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
iris_df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)     species
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %% [markdown]
# # Cleaning

# %%
iris_df.isnull().any().any()
# Out:
# False

# %% [markdown]
# There is no need to clean dataset .

# %% [markdown]
# # Visualization

# %%
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      species
# 0          0
# ...

# %%
# prompt: in iris_df in species column replace 0 with sentosa , 1 with versicolor and 2 with verginica

iris_df['species'].replace({0: 'setosa', 1: 'versicolor', 2: 'virginica'}, inplace=True)
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# ...

# %%
# @title sepal width (cm)

from matplotlib import pyplot as plt
iris_df['sepal width (cm)'].plot(kind='line', figsize=(8, 4), title='sepal width (cm)')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title sepal length (cm)

from matplotlib import pyplot as plt
iris_df['sepal length (cm)'].plot(kind='line', figsize=(8, 4), title='sepal length (cm)')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title petal length (cm)

from matplotlib import pyplot as plt
iris_df['petal length (cm)'].plot(kind='line', figsize=(8, 4), title='petal length (cm)')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title petal width (cm)

from matplotlib import pyplot as plt
iris_df['petal width (cm)'].plot(kind='line', figsize=(8, 4), title='petal width (cm)')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# In my visualization, I gained insights into how the species category of flowers changes alongside alterations in their properties.

# %% [markdown]
# # Preprocessing

# %%
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# ...

# %%
x=iris_df[["sepal length (cm)","sepal width (cm)","petal length (cm)","petal width (cm)"]]
y=iris_df["species"]

# %%
# prompt: standerize x using minmaxscaler and convert that in dataframe

# import pandas as pd
# from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()
# x_scaled = scaler.fit_transform(x)

# x_scaled_df = pd.DataFrame(x_scaled, columns=x.columns)
# x_scaled_df

# %%
iris_df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
# x_scaled_df.describe()

# %%
x
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
# prompt: split the x into train and test data

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=46)
X_train
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 33                 5.5               4.2                1.4               0.2
# 62                 6.0               2.2                4.0               1.0
# 89                 5.5               2.5                4.0               1.3
# 52                 6.9               3.1                4.9               1.5
# 21                 5.1               3.7                1.5               0.4
# ..                 ...               ...                ...               ...
# 93                 5.0               2.3                3.3               1.0
# 146                6.3               2.5                5.0               1.9
# 116                6.5               3.0                5.5               1.8
# 40                 5.0               3.5                1.3               0.3
# 69                 5.6               2.5                3.9               1.1
#
# [105 rows x 4 columns]

# %%
# X_train_scaled, X_test_scaled, y_train_scaled, y_test_scaled = train_test_split(x_scaled_df, y, test_size=0.3, random_state=45)

# %% [markdown]
# # Model Training

# %%
# prompt: import logistic regression from sklern and train the model on train data  and check the score on test data

from sklearn.linear_model import LogisticRegression

model_lr = LogisticRegression()
model_lr.fit(X_train, y_train)

model_lr.score(X_test, y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.8888888888888888

# %%
# from sklearn.linear_model import LogisticRegression

# model_lr_scaled = LogisticRegression()
# model_lr_scaled.fit(X_train_scaled, y_train_scaled)

# model_lr_scaled.score(X_test_scaled, y_test_scaled)

# %%
# # prompt: import svc from svm which is insklern and train the model on train data  and check the score on test data

# from sklearn.svm import SVC

# model_svc = SVC()
# model_svc.fit(X_train, y_train)

# model_svc.score(X_test, y_test)

# %%
# from sklearn.svm import SVC

# model_svc_scaled = SVC()
# model_svc_scaled.fit(X_train_scaled, y_train_scaled)

# model_svc_scaled.score(X_test_scaled, y_test_scaled)

# %%
# prompt: import binary tree sklern and train the model on train data  and check the score on test data

# from sklearn import tree

# model_tree = tree.DecisionTreeClassifier(criterion='gini')
# model_tree.fit(X_train, y_train)

# model_tree.score(X_test, y_test)

# %%
# from sklearn import tree

# model_tree_scaled = tree.DecisionTreeClassifier(criterion='gini')
# model_tree_scaled.fit(X_train_scaled, y_train_scaled)

# model_tree_scaled.score(X_test_scaled, y_test_scaled)

# %%
# # prompt: import random forest form sklern and train the model on train data  and check the score on test data

# from sklearn.ensemble import RandomForestClassifier

# model_rf = RandomForestClassifier(n_estimators=100)
# model_rf.fit(X_train, y_train)

# model_rf.score(X_test, y_test)

# %%
# # prompt: import naive biess sklern and train the model on train data  and check the score on test data

# from sklearn.naive_bayes import GaussianNB

# model_gnb = GaussianNB()
# model_gnb.fit(X_train, y_train)

# model_gnb.score(X_test, y_test)

# %% [markdown]
# Here i trained the data on diffrent models and got diffrent scores so i am choosing top 2 models for further process.

# %% [markdown]
# # Validation and Hypertuning

# %%
from sklearn.linear_model import LogisticRegression

model_lr = LogisticRegression()
model_lr.fit(X_train, y_train)

model_lr.score(X_test, y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.8888888888888888

# %%
# from sklearn import tree

# model_tree = tree.DecisionTreeClassifier()
# model_tree.fit(X_train, y_train)

# model_tree.score(X_test, y_test)

# %%
from sklearn.model_selection import GridSearchCV

# options = {'criterion': ('gini','entropy'),'splitter': ('best','random'),'max_depth' : list(range(1,20)) }

# gs = GridSearchCV(model_tree,options)
# gs.fit(X_train, y_train)

# %%
# gs.best_params_

# %%
# scores=gs.cv_results_['mean_test_score']
# scores

# %%
# import numpy as np
# np.argmax(scores)

# %%
# from sklearn import tree

# model_tree = tree.DecisionTreeClassifier(criterion='gini', max_depth=8, splitter= 'best')
# model_tree.fit(X_train, y_train)

# model_tree.score(X_test, y_test)

# %%
# from sklearn.linear_model import LogisticRegression

# model_lr = LogisticRegression(solver=)
# model_lr.get_params()

# model_lr.score(X_test, y_test)

# %%
# prompt: i wanna do hypertuning in logistic regression using gridsearch so do this

import numpy as np
options = {'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
          'penalty': ['l1', 'l2', 'elasticnet', 'none'],
          'C': [0.001, 0.01, 0.1, 1, 10, 100]}

gs = GridSearchCV(model_lr, options)
gs.fit(X_train, y_train)

gs.best_params_
# scores = gs.cv_results_['mean_test_score']
# np.argmax(scores)

model_lr = LogisticRegression(solver='saga', C=0.001,penalty='none')
model_lr.fit(X_train, y_train)

model_lr.score(X_test, y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %%
# from sklearn import tree

# model_tree = tree.DecisionTreeClassifier(criterion='gini', max_depth=8, splitter= 'best')
# model_tree.fit(X_train, y_train)

# model_tree.score(X_test, y_test)

# %%
# x_scaled_df

# %%
model_lr = LogisticRegression(solver='saga', C=0.001,penalty='none')
model_lr.fit(X_train, y_train)

model_lr.score(X_test, y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 0.9555555555555556

# %% [markdown]
# Here I am wrapping up the model related work and i got the accuracy of 98% on test data

# %% [markdown]
# # Model Saving

# %%
import pickle

# Save the trained model to a file
with open('iris_model', 'wb') as file:
    pickle.dump(model_lr, file)

# %%
# Load the model from the file
with open('iris_model', 'rb') as file:
    model = pickle.load(file)

# Use the loaded model to make predictions
model.score(X_train,y_train)
# Out:
# 0.9809523809523809

# %%
# X_test

# %%
print("Welcome to our ML Model, designed to predict the category of a flower based on its properties.")
print()
print()
cfr = input("Would you like to use our model? (Y or N): ")
while cfr.lower() == 'y':
    a = float(input("Enter the sepal length: "))
    b = float(input("Enter the sepal width: "))
    c = float(input("Enter the petal length: "))
    d = float(input("Enter the petal width: "))
    print()
    print("Based on the data, your flower belongs to the", model.predict([[a, b, c, d]])[0], "category.")
    print()
    cfr = input("Would you like to use the model again? (Y or N): ")
    print()
    print("Okay.")
    print()
    print()
print("Thank you for using our model!")
# Out:
# Welcome to our ML Model, designed to predict the category of a flower based on its properties.
#
#
# Would you like to use our model? (Y or N): y
# Enter the sepal length: 5
# Enter the sepal width: 3.6
# Enter the petal length: 1.4
# Enter the petal width: 0.2
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# Based on the data, your flower belongs to the setosa category.
#
# Would you like to use the model again? (Y or N): y
#
# Okay.
#
#
# Enter the sepal length: 6.7
# Enter the sepal width: 3.0
# Enter the petal length: 5.2
# Enter the petal width: 2.3
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# Based on the data, your flower belongs to the virginica category.
#
# ...
